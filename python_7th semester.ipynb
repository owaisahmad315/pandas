# %%
print("hell0 owais")
# Out:
# hell0 owais

# %%
if(5>2):
  print("five is greater than two")
# Out:
# five is greater than two

# %%
#unpacking

cars = ['ford', 'ram', 'volvo']
x,y,z = cars
print(x,z,y)
# Out:
# ford volvo ram

# %%
#global varable
x = "awsome"
def myFunction():
  print("python is " + x)
myFunction()
# Out:
# python is awsome

# %%
x = "awsome"
def myFunction():
  x = "great"
  print("python is "+ x)
myFunction()
print("python is " + x)
# Out:
# python is great
# python is awsome

# %%
#getting data type
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
#list in python
thisList = ['apple', 'banana', 'peach', 'cherry', 'cherry']
print(thisList[0])
print(len(thisList))
# Out:
# apple
# 5

# %%
#copy list
theList = ['apple', 'banana', 'peach', 'cherry', 'cherry']
copyList = theList.copy()
print(copyList)
# Out:
# ['apple', 'banana', 'peach', 'cherry', 'cherry']

# %%
#copy list
theList = ['apple', 'banana', 'peach', 'cherry', 'cherry']
copyList = list(theList)
print(copyList)
# Out:
# ['apple', 'banana', 'peach', 'cherry', 'cherry']

# %%
#join lists
list1 = ['apple', 'banana', 'peach', 'cherry', 'cherry']
list2 = ['jam', 'kheer', 'sweet', 'desert', 'dish']
joinLists = list1 + list2
print(joinLists)
# Out:
# ['apple', 'banana', 'peach', 'cherry', 'cherry', 'jam', 'kheer', 'sweet', 'desert', 'dish']

# %%
list1 = ['apple', 'banana', 'peach', 'cherry', 'cherry']
list2 = ['jam', 'kheer', 'sweet', 'desert', 'dish']

for x in list2:
  list1.append(x)
print(list1)
# Out:
# ['apple', 'banana', 'peach', 'cherry', 'cherry', 'jam', 'kheer', 'sweet', 'desert', 'dish']

# %%
#tuple
thisTuple = ('apple', 'banana', 'peach', 'cherry', 'cherry')
print(thisTuple)
# Out:
# ('apple', 'banana', 'peach', 'cherry', 'cherry')
